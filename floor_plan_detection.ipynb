# %% [markdown]
# <a href="https://colab.research.google.com/github/BKousha/FloorPlanSegmentation/blob/main/floor_plan_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CLONE REPOSITORY

# %%
# !git clone 'https://gitlab.com/maikpaixao/floor-detection.git'
# Out:
# Cloning into 'floor-detection'...
# remote: Enumerating objects: 56, done.
# remote: Total 56 (delta 0), reused 0 (delta 0), pack-reused 56
# Unpacking objects: 100% (56/56), 73.50 KiB | 3.34 MiB/s, done.

# %%
cd floordetection/

# %%
# !chmod +x download.sh
# !chmod +x install.sh
# !chmod +x run.sh

# %%
# !sh download.sh

# %%
# !sh install.sh

# %%
# !sh run.sh

# %% [markdown]
# ## INSTALL DEPENDENCIES

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## INSTALL CUDA 9

# %%
# !wget http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_9.0.176-1_amd64.deb

# %%
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn7_7.0.5.15-1+cuda9.0_amd64.deb

# %%
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn7-dev_7.0.5.15-1+cuda9.0_amd64.deb

# %%
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libnccl2_2.1.4-1+cuda9.0_amd64.deb

# %%
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libnccl-dev_2.1.4-1+cuda9.0_amd64.deb

# %%
# !dpkg -i cuda-repo-ubuntu1604_9.0.176-1_amd64.deb

# %%
# !dpkg -i libcudnn7_7.0.5.15-1+cuda9.0_amd64.deb

# %%
# !dpkg -i libcudnn7-dev_7.0.5.15-1+cuda9.0_amd64.deb

# %%
# !dpkg -i libnccl2_2.1.4-1+cuda9.0_amd64.deb

# %%
# !dpkg -i libnccl-dev_2.1.4-1+cuda9.0_amd64.deb

# %%
# !apt-get update

# %%
# !apt-get install cuda=9.0.176-1

# %%
# !apt-get install libcudnn7-dev

# %%
# !apt-get install libnccl-dev

# %%
# !apt-get install libleptonica-dev 
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev

# %%
# !python -m pip install mxnet-cu90

# %%
# !nvcc --version

# %%
cd deepfloor/

# %% [markdown]
# ## SETUP MASK-RCNN

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git

# %%
cd Mask_RCNN

# %%
# !python setup.py install

# %%
cd ..

# %% [markdown]
# ## TEST DETECTION

# %%
# !python detect.py --im_path=./teste/095.jpg
